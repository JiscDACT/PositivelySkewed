# %% [markdown]
# <a href="https://colab.research.google.com/github/JiscDACT/PositivelySkewed/blob/luke-advanced-workbook/Advanced%20Python%20Coding/Stats_101_Advanced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Advanced Python Coding
#
# This tutorial will introduce more advanced concepts in Python coding including the following:
#
# * Functions
# * Loops
# * Filtering
# * IF statements
#
# We will be using the following libraries:
# ```
# - seaborn
# - pandas
# ```

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
#  Example of a hidden code cell and instructions
#  * right click cell
#  * add form
#  * right click cell -> Form -> Hide code
#  * Click View Tab at the top -> Show/Hide Output

# %%
#@title Click here for Answers
df = sns.load_dataset('titanic')
df.head()

# %% [markdown]
# # Functions

# %% [markdown]
# A function is a block of code which will only run when it is called (example below).
#
# A function contains the function name followed by brackets and ends with a colon. Any code within the function must be indented.

# %%
# This function prints "Hello world!" when called
def sample():
  print("Hello world!")

sample()
# Out:
# Hello world!

# %% [markdown]
# There are some functions that are built into python, some of which you will have come across already:
#
# * print() - to print out to the python console
# * type() - to get the type of a variable
# * input() - to take an input from the python console
#
# You can also create your own functions, like in the code example above. This section will cover what makes a function, as well as examples of how it works.

# %% [markdown]
# ## How a function works
#
# The following keywords describe how a function is made and works
#
# * Define
# * Call
# * Pass
# * Argument
# * Parameter
#
# The image below has been anotated to show how each keyword applies to a function, using numbers in red.
#
#
# ![Screenshot 2022-05-26 160959.png](data:image/png;base64,...)
#
# Define
#
# * A function is defined using the keyword **def** (number 1)
#
# Call
#
# * Calling a function is what causes the function to be executed. To call a function, you write its name followed by parenthesis (number 2)
#
# Pass
#
# * By calling a function, the value of variables are passed to a function (number 3) - not all functions include this step, the sample(): function above is an example of this
#
# Argument
#
# * An argument is the name for a variable which has been passed to a function (number 4) - in this example, *number1* and *number2* are arguments
#
# Parameter
#
# * Arguments are assigned to local variables and are called parameters (number 5) - in this example *a* and *b* are parameters

# %% [markdown]
# The code below is a copy of the code in the image.

# %%
# The function addition takes two variables and adds them together when called
# Then prints the results to the terminal
def addition(a, b):
  print(a+b)

# Variables to be added
number1 = 5
number2 = 4

# Call the function
addition(number1, number2)

# %% [markdown]
# ## Return Values and Return Statements
#
# The **return** keyword allows you to exit a function and return a value. You can assign a function to a variable, then use it to store a result until you need it. You might do this if you want to use the result of one function in a future function, instead of printing it to the terminal.
#
# In the code example below, the variable **sum** calls the function *addition(number1, number2)* and stores the result because of the line *return a+b*. The result of the function is then output when the variable *sum* is printed.

# %%
# The function addition takes two variables and adds them together when called
def addition(a, b):
  return a+b

# Variables to be added
number1 = 5
number2 = 4

# Variable that calls the function and stores returned restult
sum = addition(number1, number2)

# Get the stored result of the function
print(sum)

# %% [markdown]
# In the code example below, printing the variable *minus* calls the function *subtraction(sum, number3)*. When the varible *sum* is passed, it calls the function *addition(number1, number2)*, and stores the result because of the line *return a+b*. The result of the *addition()* function is then passed back to the function *subtraction(sum, number3)*. The result of the *subtraction()* function is stored in variable *minus* due to the line *return c-d*, and is then output to the terminal when the variable minus is printed.

# %%
# Variables to be used
number1 = 5
number2 = 4
number3 = 18

# The function addition takes two arguments and adds them together
def addition(a, b):
  return a+b

# The function subtraction() takes two arguments and subtracts them
def subtraction(c, d):
  return c-d

# The variable sum stores the returned result from the addition() function
sum = addition(number1, number2)

# The variable minus stores the returned result from the subtraction() 
# function. The result from the addition() function is passed to the 
# subtraction() function using the variable sum
minus = subtraction(sum, number3)

# The print statement prints the variable minus, which calls the subtraction()
# function, and prints the result 
print(minus)

# %% [markdown]
# ## Inbuilt Functions
#
# As mentioned previously, Python has a range of functions that are built in and readily available, this section will cover *some* of the many funcitons that you may find useful when programming.
#
# | Function | Description                                                                                  |
# |----------|----------------------------------------------------------------------------------------------|
# | print()  | Print to the standard output (normally the terminal)                                         |
# | input()  | Have a user enter input from the terminal (write text then hit enter)                                                    |
# | len()    | Returns the length of an object (can be used with strings to count its number of characters) |
# | type()   | Returns the type of an object i.e., string, integer, float etc                               |
# | int()    | Returns an integer number (i.e., turn a string to an integer)                                |
# | str()    | Returns a string object (i.e., turn a float to a string)                                     |
# | float()  | Returns a floating point number (i.e., turn an integer into a decimal)                       |
#
# A full list of these inbuilt functions, their descriptions, and examples of use can be found [here](https://www.w3schools.com/python/python_ref_functions.asp).
#
# The code below shows an example of some of these inbuilt functions being used.

# %%
# Capture user's first name
print("What is your first name?") # Print function
name = input() # Input function

# Capture user's age
print("What is your age?")
age = input()

# Get string length
length = len(name)  # Len function
print("You name is", length, "characters long")

# Convert age variable from string to an integer
print("Your age is currently a string:", type(age)) # Type function
int_age = int(age)  # Int function
print("Your age has been converted to an integer", type(int_age))

# %% [markdown]
# ### Exercise 1
#
# 1. Write a function that multiplies two numbers together and returns the result, then prints the result.
#
# 2. Write code for the following task: use the input() function to store a person's first name in one variable, and their last name in a second variable. Then write one function that counts the number of characters in each variable and returns the result to another variable, and prints the result.

# %%
# Exercise 1.1

# Write your code here

# %%
#@title Example Solution 1

# Variables to be multiplied
number1 = 10
number2 = 4

# Function to multiply variables and return result
def multiply(a, b):
  return a*b

# Variable output to store the result of the function multiply()
output = multiply(number1, number2)

# Print the result
print(output)

# %%
# Exercise 1.2

# Write your code here

# %%
#@title Example Solution 2

# Input variables
first_name = input()
last_name = input()

# Function to count the characters in each variable
def characters(f_name, l_name):
  a = len(f_name)
  b = len(l_name)
  return a+b

# Variable to store the result
sum = characters(first_name, last_name)

# Print the result
print("\n In total your name is", sum, "characters long")

# %% [markdown]
# # Loops
#
# There are two types of loops in python:
#
# * while loops
# * for loops

# %% [markdown]
# ### While Loops
#
# The while loop executes code statements, as long as a condition is true.
#
# For example: *while* a variable is less than 6, repeat these actions.
#
# The code below shows this example in python code. A *while* statement is structured by using the keyword *while*, followed by the condition, then a colon. The code block to be executed is then written below with an indentation.

# %%
# Condition variable
i = 1

# While loop
while i < 6:
  print(i) # Print the value of i
  i+=1 # Increase the Value of i to prevent an infinite loop

# %% [markdown]
# * The variable *i* is used as a condition variable. It allows the loop to repeat
# * The keyword *while* creates a loop
# * *i < 6* creates a condition. The loop will repeat untill the condition stops being true
# * *Print(i)* is our statement to be executed as long as the loop repeats
# * *i+=1* increments the condition variable, so eventually i will equal 6 and the loop will stop. (Forgetting this will cause an infinite loop!)

# %% [markdown]
# #### Else Statement
#
# The else statement runs code when the condition is no longer true.

# %%
# Condition variable
i = 0

# While loop
while i < 6:
  print(i) # Print the value of a
  i+=1
else:
  print("i is greater than 5")

# %% [markdown]
# ## For Loops
#
# With the *for* keyword, a code block can be executed, one for each item in a list, dictionary etc.
#
# A *for loop* is structured by using the keywords *for* followed by a variable, and the keyword *in* followed by a sequence. The code block to be executed is then written below with an indentation.
#
# An example is shown below:

# %%
# Variable containing a list
fruits = ["apple", "watermelon", "kiwi"]

# For loop
for x in fruits:
  print(x) # Print the items in the list

# %% [markdown]
# * The variable fruits contains a list of three strings
# * The keyword *for* is used to create the for loop
# * The keyword *in* and the variable fruits identifies the list we want to loop through
# * Print(x) is our statement to be executed untill the loop is finished iterating through the list
#
# An example of this is shown below. Using the HESA data file from the Python Essentials Workbook, a *for* loop prints out the individual years.

# %%
# Import packages
from google.colab import files
import pandas as pd

uploaded = files.upload() # Upload HESA file

# %%
 # Create a dataframe
df = pd.read_csv('oc031-chart-1.csv', skiprows=10) 

# For loop to print the individual years
for year in df["Year"]:
  print(year)
# Out:
# 2014/15
# 2015/16
# 2016/17
# 2017/18
# 2018/19
# 2019/20
